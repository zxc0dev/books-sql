# %%
from src.pipeline import run_pipeline
from src.db_setup import create_database, create_tables

# %%
create_database()
# Out:
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Database 'library' already exists.

# %%
create_tables()
# Out:
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Running 03_schema.sql...
# 2026-04-11 20:57:01 | INFO     | src.db | Executed: D:\projects\sql-books\sql\sql_create\03_schema.sql
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Running 04_staging_schema.sql...
# 2026-04-11 20:57:01 | INFO     | src.db | Executed: D:\projects\sql-books\sql\sql_create\04_staging_schema.sql
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Running 05_quarantine_schema.sql...
# 2026-04-11 20:57:01 | INFO     | src.db | Executed: D:\projects\sql-books\sql\sql_create\05_quarantine_schema.sql
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Creating index: 01_books_indexes.sql
# 2026-04-11 20:57:01 | INFO     | src.db | Executed: D:\projects\sql-books\sql\sql_indexes\01_books_indexes.sql
# 2026-04-11 20:57:01 | INFO     | src.db_setup | Creating index: 02_ratings_indexes.sql
# 2026-04-11 20:57:01 | INFO     | src.db | Executed: D:\projects\sql-books\sql\sql_indexes\02_ratings_indexes.sql
# ...

# %%
run_pipeline()
# Out:
# 2026-04-11 20:57:01 | INFO     | src.pipeline | === Pipeline started ===
# 2026-04-11 20:57:01 | INFO     | src.pipeline | Downloading data...
# 2026-04-11 20:57:01 | INFO     | src.pipeline | None
# 2026-04-11 20:57:01 | INFO     | src.pipeline | Validating data...
# 2026-04-11 20:57:01 | INFO     | src.validate | === VALIDATION PIPELINE START ===
# 2026-04-11 20:57:01 | INFO     | src.validate | Loading raw data...
# Data exists in D:\projects\sql-books\data\01_raw. Skipping.
# 2026-04-11 20:57:04 | INFO     | src.validate | Loaded — books: 271,360  users: 278,858  ratings: 1,149,780
# 2026-04-11 20:57:04 | INFO     | src.validate | Standardizing columns...
# 2026-04-11 20:57:07 | INFO     | src.validate | Running schema validation...
# 2026-04-11 20:57:09 | INFO     | src.validate | Referential integrity — orphan ISBNs: 132,823  orphan users: 1,095
# 2026-04-11 20:57:09 | INFO     | src.validate | Duplicates ['ISBN']: 308 quarantined
# ...

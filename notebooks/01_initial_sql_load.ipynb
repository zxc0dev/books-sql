# %%
from src.pipeline import run_pipeline
from src.db_setup import create_database, create_tables
from src.logger import log_session
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from src.pipeline import run_pipeline
# ----> 2 from src.sql_execute import create_database, create_tables
#       3 from src.logger import log_session
#
# ImportError: cannot import name 'create_database' from 'src.sql_execute' (D:\projects\sql-books\src\sql_execute.py)

# %%
with log_session():
    create_database()
    create_tables()
    run_pipeline()
# Out:
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Database 'library' already exists.
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Running 03_schema.sql...
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_create\03_schema.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Running 04_staging_schema.sql...
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_create\04_staging_schema.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Running 05_quarantine_schema.sql...
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_create\05_quarantine_schema.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating index: 01_books_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_indexes\01_books_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating index: 02_ratings_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_indexes\02_ratings_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating index: 03_audit_log_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_indexes\03_audit_log_indexes.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating trigger: 01_func_audit_log.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_triggers\01_func_audit_log.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating trigger: 02_trg_audit_log.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_triggers\02_trg_audit_log.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating view: 01_view_average_rating.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_views\01_view_average_rating.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating view: 02_view_books_enriched.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_views\02_view_books_enriched.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating view: 03_view_average_rating_per_author.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_views\03_view_average_rating_per_author.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | Creating view: 04_view_users_rating_count.sql
# 2026-04-11 22:38:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_views\04_view_users_rating_count.sql
# 2026-04-11 22:38:14 | INFO    | src.db_setup | === Schema setup complete ===
# 2026-04-11 22:38:14 | INFO    | src.pipeline | === Pipeline started ===
# 2026-04-11 22:38:14 | INFO    | src.pipeline | Downloading data...
# 2026-04-11 22:38:14 | INFO    | src.pipeline | None
# 2026-04-11 22:38:14 | INFO    | src.pipeline | Validating data...
# 2026-04-11 22:38:14 | INFO    | src.validate | === VALIDATION PIPELINE START ===
# 2026-04-11 22:38:14 | INFO    | src.validate | Loading raw data...
# Data exists in D:\projects\sql-books\data\01_raw. Skipping.
# 2026-04-11 22:38:17 | INFO    | src.validate | Loaded — books: 271,360  users: 278,858  ratings: 1,149,780
# 2026-04-11 22:38:17 | INFO    | src.validate | Standardizing columns...
# 2026-04-11 22:38:20 | INFO    | src.validate | Running schema validation...
# 2026-04-11 22:38:23 | INFO    | src.validate | Referential integrity — orphan ISBNs: 132,823  orphan users: 1,095
# 2026-04-11 22:38:23 | INFO    | src.validate | Duplicates ['ISBN']: 308 quarantined
# 2026-04-11 22:38:23 | INFO    | src.validate | Duplicates ['User-ID']: 0 quarantined
# 2026-04-11 22:38:24 | INFO    | src.validate | Duplicates ['User-ID', 'ISBN']: 0 quarantined
# 2026-04-11 22:38:26 | INFO    | src.validate | Exported processed and quarantine files.
# 2026-04-11 22:38:26 | INFO    | src.validate | Books: total=271,360  clean=266,345 (98.2%)  quarantined=5,015 (1.8%)
# 2026-04-11 22:38:26 | INFO    | src.validate |    4,558x  Year out of range: 0
# 2026-04-11 22:38:26 | INFO    | src.validate |      308x  Duplicate ISBN
# 2026-04-11 22:38:26 | INFO    | src.validate |        7x  Year out of range: 2030
# 2026-04-11 22:38:26 | INFO    | src.validate |        5x  Book-Author too short: X | Year out of range: 0
# 2026-04-11 22:38:26 | INFO    | src.validate |        4x  Book-Author too short: N
# 2026-04-11 22:38:26 | INFO    | src.validate | Users: total=278,858  clean=278,780 (100.0%)  quarantined=78 (0.0%)
# 2026-04-11 22:38:26 | INFO    | src.validate |        8x  Age out of range: 123
# 2026-04-11 22:38:26 | INFO    | src.validate |        5x  Age out of range: 148
# 2026-04-11 22:38:26 | INFO    | src.validate |        5x  Age out of range: 124
# 2026-04-11 22:38:26 | INFO    | src.validate |        4x  Age out of range: 204
# 2026-04-11 22:38:26 | INFO    | src.validate |        3x  Age out of range: 141
# 2026-04-11 22:38:26 | INFO    | src.validate | Ratings: total=1,149,780  clean=1,015,862 (88.4%)  quarantined=133,918 (11.6%)
# 2026-04-11 22:38:26 | INFO    | src.validate |   132,823x  ISBN not found in books
# 2026-04-11 22:38:26 | INFO    | src.validate |    1,095x  User-ID not found in users
# 2026-04-11 22:38:26 | INFO    | src.validate | === VALIDATION PIPELINE DONE ===
# 2026-04-11 22:38:26 | INFO    | src.pipeline | Loading to staging...
# 2026-04-11 22:38:28 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\01_load_staging.sql
# 2026-04-11 22:38:28 | INFO    | src.pipeline | Running data integrity check...
# 2026-04-11 22:38:28 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\02_data_integrity_check.sql
# 2026-04-11 22:38:28 | INFO    | src.pipeline | Loading authors...
# 2026-04-11 22:38:31 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\03_load_authors.sql
# 2026-04-11 22:38:31 | INFO    | src.pipeline | Loading publishers...
# 2026-04-11 22:38:31 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\04_load_publishers.sql
# 2026-04-11 22:38:31 | INFO    | src.pipeline | Loading books...
# 2026-04-11 22:38:53 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\05_load_books.sql
# 2026-04-11 22:38:53 | INFO    | src.pipeline | Loading users...
# 2026-04-11 22:39:02 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\06_load_users.sql
# 2026-04-11 22:39:02 | INFO    | src.pipeline | Loading ratings...
# 2026-04-11 22:40:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_load\07_load_ratings.sql
# 2026-04-11 22:40:14 | INFO    | src.pipeline | Cleaning up staging...
# 2026-04-11 22:40:14 | INFO    | src.db | Executed: D:\projects\sql-books\sql\sql_create\06_cleanup_staging.sql
# 2026-04-11 22:40:14 | INFO    | src.pipeline | === Pipeline completed successfully ===

# %%
from sqlalchemy import create_engine
from src.config import (DB_MAIN, DB_CREATED)

# %%
# Out:
# 2026-04-11 19:41:28 | INFO     | src.validate | === VALIDATION PIPELINE START ===
# 2026-04-11 19:41:28 | INFO     | src.validate | Loading raw data...
# 2026-04-11 19:41:31 | INFO     | src.validate | Loaded — books: 271,360  users: 278,858  ratings: 1,149,780
# 2026-04-11 19:41:31 | INFO     | src.validate | Standardizing columns...
# 2026-04-11 19:41:34 | INFO     | src.validate | Running schema validation...
# 2026-04-11 19:41:36 | INFO     | src.validate | Referential integrity — orphan ISBNs: 132,823  orphan users: 1,095
# 2026-04-11 19:41:36 | INFO     | src.validate | Duplicates ['ISBN']: 308 quarantined
# 2026-04-11 19:41:36 | INFO     | src.validate | Duplicates ['User-ID']: 0 quarantined
# 2026-04-11 19:41:36 | INFO     | src.validate | Duplicates ['User-ID', 'ISBN']: 0 quarantined
# 2026-04-11 19:41:39 | INFO     | src.validate | Exported processed and quarantine files.
# 2026-04-11 19:41:39 | INFO     | src.validate | Books: total=271,360  clean=266,345 (98.2%)  quarantined=5,015 (1.8%)
# 2026-04-11 19:41:39 | INFO     | src.validate |    4,558x  Year out of range: 0
# 2026-04-11 19:41:39 | INFO     | src.validate |      308x  Duplicate ISBN
# 2026-04-11 19:41:39 | INFO     | src.validate |        7x  Year out of range: 2030
# 2026-04-11 19:41:39 | INFO     | src.validate |        5x  Book-Author too short: X | Year out of range: 0
# 2026-04-11 19:41:39 | INFO     | src.validate |        4x  Book-Author too short: N
# 2026-04-11 19:41:39 | INFO     | src.validate | Users: total=278,858  clean=278,780 (100.0%)  quarantined=78 (0.0%)
# 2026-04-11 19:41:39 | INFO     | src.validate |        8x  Age out of range: 123
# 2026-04-11 19:41:39 | INFO     | src.validate |        5x  Age out of range: 148
# 2026-04-11 19:41:39 | INFO     | src.validate |        5x  Age out of range: 124
# 2026-04-11 19:41:39 | INFO     | src.validate |        4x  Age out of range: 204
# 2026-04-11 19:41:39 | INFO     | src.validate |        3x  Age out of range: 141
# 2026-04-11 19:41:39 | INFO     | src.validate | Ratings: total=1,149,780  clean=1,015,862 (88.4%)  quarantined=133,918 (11.6%)
# 2026-04-11 19:41:39 | INFO     | src.validate |   132,823x  ISBN not found in books
# 2026-04-11 19:41:39 | INFO     | src.validate |    1,095x  User-ID not found in users
# 2026-04-11 19:41:39 | INFO     | src.validate | === VALIDATION PIPELINE DONE ===

# %%
# %load_ext sql

# connection for main db
engine = create_engine(DB_MAIN)
# %sql engine

# %sql --file ../sql/sql_create/01_terminate_backend_sessions.sql
# %sql --file ../sql/sql_create/02_db_create.sql
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# ++
# ||
# ++
# ++

# %%
# connection for created db
engine = create_engine(DB_CREATED)
# %sql engine

# tables
# %sql --file ../sql/sql_create/03_schema.sql

# %sql --file ../sql/sql_create/04_staging_schema.sql

# %sql --file ../sql/sql_create/05_quarantine_schema.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ++
# ||
# ++
# ++

# %%
# triggers
# %sql --file ../sql/sql_triggers/01_fn_audit_log.sql
# %sql --file ../sql/sql_triggers/02_trg_audit_log.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ++
# ||
# ++
# ++

# %%
# loading into staging table
# %sql --file ../sql/sql_load/01_load_staging.sql
# %sql --file ../sql/sql_load/02_data_integrity_check.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 266345 rows affected.
# 278780 rows affected.
# 1015862 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'

# %%
# loading into main tables
# %sql --file ../sql/sql_load/03_load_authors.sql
# %sql --file ../sql/sql_load/04_load_publishers.sql
# %sql --file ../sql/sql_load/05_load_books.sql
# %sql --file ../sql/sql_load/06_load_users.sql
# %sql --file ../sql/sql_load/07_load_ratings.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 98017 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 16163 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 266343 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 278780 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 1015860 rows affected.
# ++
# ||
# ++
# ++

# %%
# indexes
# %sql --file ../sql/sql_indexes/01_books_indexes.sql
# %sql --file ../sql/sql_indexes/02_ratings_indexes.sql
# %sql --file ../sql/sql_indexes/03_audit_log_indexes.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ++
# ||
# ++
# ++

# %%
# %sql --file ../sql/sql_create/06_cleanup_staging.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ++
# ||
# ++
# ++

# %%
# %sql --file ../sql/sql_views/01_view_average_rating.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ++
# ||
# ++
# ++

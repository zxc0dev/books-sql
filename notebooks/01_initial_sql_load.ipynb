# %%
from src.pipeline import run_pipeline
from src.db_init.db_setup import drop_database, create_database, create_tables

# %%
drop_database()
create_database()
create_tables()
run_pipeline()
# Out:
# 22:35:27.205 | INFO    | src.db_init.db_setup - Database 'library' dropped.
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Database 'library' dropped.
# 22:35:27.427 | INFO    | src.db_init.db_setup - Database 'library' created.
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Database 'library' created.
# 22:35:27.486 | INFO    | src.db_init.db_setup - Running schema.sql...
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Running schema.sql...
# 22:35:27.572 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_tables\schema.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_tables\schema.sql
# 22:35:27.577 | INFO    | src.db_init.db_setup - Creating index: idx_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Creating index: idx_audit_log.sql
# 22:35:27.585 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_audit_log.sql
# 22:35:27.589 | INFO    | src.db_init.db_setup - Creating index: idx_books.sql
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Creating index: idx_books.sql
# 22:35:27.598 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_books.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_books.sql
# 22:35:27.602 | INFO    | src.db_init.db_setup - Creating index: idx_ratings.sql
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Creating index: idx_ratings.sql
# 22:35:27.611 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_ratings.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_indexes\idx_ratings.sql
# 22:35:27.614 | INFO    | src.db_init.db_setup - Creating trigger: 01_func_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Creating trigger: 01_func_audit_log.sql
# 22:35:27.627 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_triggers\01_func_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_triggers\01_func_audit_log.sql
# 22:35:27.629 | INFO    | src.db_init.db_setup - Creating trigger: 02_trg_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | Creating trigger: 02_trg_audit_log.sql
# 22:35:27.634 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_triggers\02_trg_audit_log.sql
# 2026-04-12 22:35:27 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\sql\sql_triggers\02_trg_audit_log.sql
# 22:35:27.637 | INFO    | src.db_init.db_setup - === Schema setup complete ===
# 2026-04-12 22:35:27 | INFO    | src.db_init.db_setup | === Schema setup complete ===
# 22:35:29.843 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8446
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 2026-04-12 22:35:29 | INFO    | prefect | Starting temporary server on http://127.0.0.1:8446
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 22:35:36.303 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/health "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/health "HTTP/1.1 200 OK"
# 22:35:36.333 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/admin/version "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/admin/version "HTTP/1.1 200 OK"
# 22:35:36.345 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/csrf-token?client=52b0108a-ea12-4306-aee9-897cd063cd84 "HTTP/1.1 422 Unprocessable Entity"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/csrf-token?client=52b0108a-ea12-4306-aee9-897cd063cd84 "HTTP/1.1 422 Unprocessable Entity"
# 22:35:36.363 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/flows/ "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/flows/ "HTTP/1.1 200 OK"
# 22:35:36.407 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/ "HTTP/1.1 201 Created"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/ "HTTP/1.1 201 Created"
# 22:35:36.457 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a/set_state "HTTP/1.1 201 Created"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a/set_state "HTTP/1.1 201 Created"
# 22:35:36.475 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a "HTTP/1.1 200 OK"
# 22:35:36.479 | INFO    | Flow run 'illegal-puffin' - Beginning flow run 'illegal-puffin' for flow 'books-pipeline'
# 2026-04-12 22:35:36 | INFO    | prefect.flow_runs | Beginning flow run 'illegal-puffin' for flow 'books-pipeline'
# 22:35:36.488 | INFO    | src.pipeline - === Pipeline started ===
# 2026-04-12 22:35:36 | INFO    | src.pipeline | === Pipeline started ===
# 22:35:36.530 | INFO    | src.tasks.download - Data exists in D:\projects\books-sql\data\01_raw. Skipping.
# 2026-04-12 22:35:36 | INFO    | src.tasks.download | Data exists in D:\projects\books-sql\data\01_raw. Skipping.
# 22:35:36.536 | INFO    | Task run 'download-data-597' - Finished in state Completed()
# 2026-04-12 22:35:36 | INFO    | prefect.task_runs | Finished in state Completed()
# 22:35:36.542 | INFO    | src.tasks.validate - === VALIDATION PIPELINE START ===
# 2026-04-12 22:35:36 | INFO    | src.tasks.validate | === VALIDATION PIPELINE START ===
# 22:35:36.544 | INFO    | src.tasks.validate - Loading raw data...
# 2026-04-12 22:35:36 | INFO    | src.tasks.validate | Loading raw data...
# 22:35:36.560 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/admin/version "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/admin/version "HTTP/1.1 200 OK"
# 22:35:36.590 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/flows/6db4eb26-9016-4c37-a0b6-b208e60d79b5 "HTTP/1.1 200 OK"
# 2026-04-12 22:35:36 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/flows/6db4eb26-9016-4c37-a0b6-b208e60d79b5 "HTTP/1.1 200 OK"
# 22:35:38.501 | INFO    | httpx - HTTP Request: GET http://127.0.0.1:8446/api/csrf-token?client=14a84330-b6ff-4779-b13d-bde066abcca4 "HTTP/1.1 422 Unprocessable Entity"
# 2026-04-12 22:35:38 | INFO    | httpx | HTTP Request: GET http://127.0.0.1:8446/api/csrf-token?client=14a84330-b6ff-4779-b13d-bde066abcca4 "HTTP/1.1 422 Unprocessable Entity"
# 22:35:38.524 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 2026-04-12 22:35:38 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 22:35:38.991 | INFO    | src.tasks.validate - Loaded — books: 271,360  users: 278,858  ratings: 1,149,780
# 2026-04-12 22:35:38 | INFO    | src.tasks.validate | Loaded — books: 271,360  users: 278,858  ratings: 1,149,780
# 22:35:38.993 | INFO    | src.tasks.validate - Standardizing columns...
# 2026-04-12 22:35:38 | INFO    | src.tasks.validate | Standardizing columns...
# 22:35:41.477 | INFO    | src.tasks.validate - Running schema validation...
# 2026-04-12 22:35:41 | INFO    | src.tasks.validate | Running schema validation...
# 22:35:43.631 | INFO    | src.tasks.validate - Referential integrity — orphan ISBNs: 132,823  orphan users: 1,095
# 2026-04-12 22:35:43 | INFO    | src.tasks.validate | Referential integrity — orphan ISBNs: 132,823  orphan users: 1,095
# 22:35:43.794 | INFO    | src.tasks.validate - Duplicates ['ISBN']: 308 quarantined
# 2026-04-12 22:35:43 | INFO    | src.tasks.validate | Duplicates ['ISBN']: 308 quarantined
# 22:35:43.986 | INFO    | src.tasks.validate - Duplicates ['User-ID']: 0 quarantined
# 2026-04-12 22:35:43 | INFO    | src.tasks.validate | Duplicates ['User-ID']: 0 quarantined
# 22:35:44.274 | INFO    | src.tasks.validate - Duplicates ['User-ID', 'ISBN']: 0 quarantined
# 2026-04-12 22:35:44 | INFO    | src.tasks.validate | Duplicates ['User-ID', 'ISBN']: 0 quarantined
# 22:35:47.285 | INFO    | src.tasks.validate - Exported processed and quarantine files.
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate | Exported processed and quarantine files.
# 22:35:47.287 | INFO    | src.tasks.validate - Books: total=271,360  clean=266,345 (98.2%)  quarantined=5,015 (1.8%)
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate | Books: total=271,360  clean=266,345 (98.2%)  quarantined=5,015 (1.8%)
# 22:35:47.290 | INFO    | src.tasks.validate -    4,558x  Year out of range: 0
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |    4,558x  Year out of range: 0
# 22:35:47.290 | INFO    | src.tasks.validate -      308x  Duplicate ISBN
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |      308x  Duplicate ISBN
# 22:35:47.293 | INFO    | src.tasks.validate -        7x  Year out of range: 2030
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        7x  Year out of range: 2030
# 22:35:47.295 | INFO    | src.tasks.validate -        5x  Book-Author too short: X | Year out of range: 0
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        5x  Book-Author too short: X | Year out of range: 0
# 22:35:47.296 | INFO    | src.tasks.validate -        4x  Book-Author too short: N
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        4x  Book-Author too short: N
# 22:35:47.296 | INFO    | src.tasks.validate - Users: total=278,858  clean=278,780 (100.0%)  quarantined=78 (0.0%)
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate | Users: total=278,858  clean=278,780 (100.0%)  quarantined=78 (0.0%)
# 22:35:47.299 | INFO    | src.tasks.validate -        8x  Age out of range: 123
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        8x  Age out of range: 123
# 22:35:47.303 | INFO    | src.tasks.validate -        5x  Age out of range: 148
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        5x  Age out of range: 148
# 22:35:47.305 | INFO    | src.tasks.validate -        5x  Age out of range: 124
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        5x  Age out of range: 124
# 22:35:47.306 | INFO    | src.tasks.validate -        4x  Age out of range: 204
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        4x  Age out of range: 204
# 22:35:47.308 | INFO    | src.tasks.validate -        3x  Age out of range: 141
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |        3x  Age out of range: 141
# 22:35:47.310 | INFO    | src.tasks.validate - Ratings: total=1,149,780  clean=1,015,862 (88.4%)  quarantined=133,918 (11.6%)
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate | Ratings: total=1,149,780  clean=1,015,862 (88.4%)  quarantined=133,918 (11.6%)
# 22:35:47.317 | INFO    | src.tasks.validate -   132,823x  ISBN not found in books
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |   132,823x  ISBN not found in books
# 22:35:47.319 | INFO    | src.tasks.validate -    1,095x  User-ID not found in users
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate |    1,095x  User-ID not found in users
# 22:35:47.322 | INFO    | src.tasks.validate - === VALIDATION PIPELINE DONE ===
# 2026-04-12 22:35:47 | INFO    | src.tasks.validate | === VALIDATION PIPELINE DONE ===
# 22:35:47.393 | INFO    | Task run 'validate-data-957' - Finished in state Completed()
# 2026-04-12 22:35:47 | INFO    | prefect.task_runs | Finished in state Completed()
# 22:35:47.564 | INFO    | src.tasks.load - Loading CSVs into staging...
# 2026-04-12 22:35:47 | INFO    | src.tasks.load | Loading CSVs into staging...
# 22:35:48.947 | INFO    | src.tasks.load - Loaded raw.raw_books from books_good.csv
# 2026-04-12 22:35:48 | INFO    | src.tasks.load | Loaded raw.raw_books from books_good.csv
# 22:35:49.057 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 2026-04-12 22:35:49 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 22:35:49.243 | INFO    | src.tasks.load - Loaded raw.raw_users from users_good.csv
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Loaded raw.raw_users from users_good.csv
# 22:35:49.788 | INFO    | src.tasks.load - Loaded raw.raw_ratings from ratings_good.csv
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Loaded raw.raw_ratings from ratings_good.csv
# 22:35:49.796 | INFO    | src.tasks.load - Raw loaded.
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Raw loaded.
# 22:35:49.800 | INFO    | Task run 'load-raw-edc' - Finished in state Completed()
# 2026-04-12 22:35:49 | INFO    | prefect.task_runs | Finished in state Completed()
# 22:35:49.805 | INFO    | src.tasks.load - Loading CSVs into quarantine...
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Loading CSVs into quarantine...
# 22:35:49.834 | INFO    | src.tasks.load - Loaded quarantine.quarantine_books from books_quarantine.csv
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Loaded quarantine.quarantine_books from books_quarantine.csv
# 22:35:49.840 | INFO    | src.tasks.load - Loaded quarantine.quarantine_users from users_quarantine.csv
# 2026-04-12 22:35:49 | INFO    | src.tasks.load | Loaded quarantine.quarantine_users from users_quarantine.csv
# 22:35:50.127 | INFO    | src.tasks.load - Loaded quarantine.quarantine_ratings from ratings_quarantine.csv
# 2026-04-12 22:35:50 | INFO    | src.tasks.load | Loaded quarantine.quarantine_ratings from ratings_quarantine.csv
# 22:35:50.133 | INFO    | src.tasks.load - Quarantine loaded.
# 2026-04-12 22:35:50 | INFO    | src.tasks.load | Quarantine loaded.
# 22:35:50.137 | INFO    | Task run 'load-quarantine-63b' - Finished in state Completed()
# 2026-04-12 22:35:50 | INFO    | prefect.task_runs | Finished in state Completed()
# 22:35:50.147 | INFO    | src.tasks.dbt - Running dbt models...
# 2026-04-12 22:35:50 | INFO    | src.tasks.dbt | Running dbt models...
# 22:35:51.083 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 2026-04-12 22:35:51 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 22:35:56.804 | INFO    | src.tasks.dbt - 20:35:53  Running with dbt=1.11.8
# 20:35:54  Registered adapter: postgres=1.10.0
# 20:35:55  Found 9 models, 27 data tests, 582 macros
# 20:35:55
# 20:35:55  Concurrency: 4 threads (target='dev')
# 20:35:55
# 20:35:55  1 of 9 START sql view model staging.stg_books .................................. [RUN]
# 20:35:55  2 of 9 START sql view model staging.stg_ratings ................................ [RUN]
# 20:35:55  3 of 9 START sql view model staging.stg_users .................................. [RUN]
# 20:35:55  1 of 9 ERROR creating sql view model staging.stg_books ......................... [ERROR in 0.13s]
# 20:35:55  3 of 9 ERROR creating sql view model staging.stg_users ......................... [ERROR in 0.13s]
# 20:35:55  2 of 9 ERROR creating sql view model staging.stg_ratings ....................... [ERROR in 0.13s]
# 20:35:55  4 of 9 SKIP relation dim.dim_authors ........................................... [SKIP]
# 20:35:55  5 of 9 SKIP relation dim.dim_publishers ........................................ [SKIP]
# 20:35:55  6 of 9 SKIP relation dim.dim_users ............................................. [SKIP]
# 20:35:55  7 of 9 SKIP relation dim.dim_books ............................................. [SKIP]
# 20:35:55  8 of 9 SKIP relation fact.fact_ratings ......................................... [SKIP]
# 20:35:55  9 of 9 SKIP relation marts.avg_rating .......................................... [SKIP]
# 20:35:55
# 20:35:55  Finished running 5 table models, 4 view models in 0 hours 0 minutes and 0.55 seconds (0.55s).
# 20:35:55
# 20:35:55  Completed with 3 errors, 0 partial successes, and 0 warnings:
# 20:35:55
# 20:35:55  Failure in model stg_books (models\staging\stg_books.sql)
# 20:35:55    Database Error in model stg_books (models\staging\stg_books.sql)
#   relation "raw_books" does not exist
#   LINE 13: FROM raw_books
#                 ^
#   compiled code at target\run\books\models\staging\stg_books.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_books.sql
# 20:35:55
# 20:35:55  Failure in model stg_users (models\staging\stg_users.sql)
# 20:35:55    Database Error in model stg_users (models\staging\stg_users.sql)
#   relation "raw_users" does not exist
#   LINE 11: FROM raw_users
#                 ^
#   compiled code at target\run\books\models\staging\stg_users.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_users.sql
# 20:35:55
# 20:35:55  Failure in model stg_ratings (models\staging\stg_ratings.sql)
# 20:35:55    Database Error in model stg_ratings (models\staging\stg_ratings.sql)
#   relation "raw_ratings" does not exist
#   LINE 11: FROM raw_ratings
#                 ^
#   compiled code at target\run\books\models\staging\stg_ratings.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_ratings.sql
# 20:35:55
# 20:35:55  Done. PASS=0 WARN=0 ERROR=3 SKIP=6 NO-OP=0 TOTAL=9
# 2026-04-12 22:35:56 | INFO    | src.tasks.dbt | 20:35:53  Running with dbt=1.11.8
# 20:35:54  Registered adapter: postgres=1.10.0
# 20:35:55  Found 9 models, 27 data tests, 582 macros
# 20:35:55
# 20:35:55  Concurrency: 4 threads (target='dev')
# 20:35:55
# 20:35:55  1 of 9 START sql view model staging.stg_books .................................. [RUN]
# 20:35:55  2 of 9 START sql view model staging.stg_ratings ................................ [RUN]
# 20:35:55  3 of 9 START sql view model staging.stg_users .................................. [RUN]
# 20:35:55  1 of 9 ERROR creating sql view model staging.stg_books ......................... [ERROR in 0.13s]
# 20:35:55  3 of 9 ERROR creating sql view model staging.stg_users ......................... [ERROR in 0.13s]
# 20:35:55  2 of 9 ERROR creating sql view model staging.stg_ratings ....................... [ERROR in 0.13s]
# 20:35:55  4 of 9 SKIP relation dim.dim_authors ........................................... [SKIP]
# 20:35:55  5 of 9 SKIP relation dim.dim_publishers ........................................ [SKIP]
# 20:35:55  6 of 9 SKIP relation dim.dim_users ............................................. [SKIP]
# 20:35:55  7 of 9 SKIP relation dim.dim_books ............................................. [SKIP]
# 20:35:55  8 of 9 SKIP relation fact.fact_ratings ......................................... [SKIP]
# 20:35:55  9 of 9 SKIP relation marts.avg_rating .......................................... [SKIP]
# 20:35:55
# 20:35:55  Finished running 5 table models, 4 view models in 0 hours 0 minutes and 0.55 seconds (0.55s).
# 20:35:55
# 20:35:55  Completed with 3 errors, 0 partial successes, and 0 warnings:
# 20:35:55
# 20:35:55  Failure in model stg_books (models\staging\stg_books.sql)
# 20:35:55    Database Error in model stg_books (models\staging\stg_books.sql)
#   relation "raw_books" does not exist
#   LINE 13: FROM raw_books
#                 ^
#   compiled code at target\run\books\models\staging\stg_books.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_books.sql
# 20:35:55
# 20:35:55  Failure in model stg_users (models\staging\stg_users.sql)
# 20:35:55    Database Error in model stg_users (models\staging\stg_users.sql)
#   relation "raw_users" does not exist
#   LINE 11: FROM raw_users
#                 ^
#   compiled code at target\run\books\models\staging\stg_users.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_users.sql
# 20:35:55
# 20:35:55  Failure in model stg_ratings (models\staging\stg_ratings.sql)
# 20:35:55    Database Error in model stg_ratings (models\staging\stg_ratings.sql)
#   relation "raw_ratings" does not exist
#   LINE 11: FROM raw_ratings
#                 ^
#   compiled code at target\run\books\models\staging\stg_ratings.sql
# 20:35:55
# 20:35:55    compiled code at target\compiled\books\models\staging\stg_ratings.sql
# 20:35:55
# 20:35:55  Done. PASS=0 WARN=0 ERROR=3 SKIP=6 NO-OP=0 TOTAL=9
# 22:35:56.812 | ERROR   | src.tasks.dbt -
# 2026-04-12 22:35:56 | ERROR   | src.tasks.dbt |
# 22:35:56.812 | ERROR   | Task run 'dbt-run-edf' - Task run failed with exception: RuntimeError('dbt run failed')
# Traceback (most recent call last):
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1014, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 25, in dbt_run
#     _run_dbt("run")
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 20, in _run_dbt
#     raise RuntimeError(f"dbt {command} failed")
# RuntimeError: dbt run failed
# 2026-04-12 22:35:56 | ERROR   | prefect.task_runs | Task run failed with exception: RuntimeError('dbt run failed')
# Traceback (most recent call last):
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1014, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 25, in dbt_run
#     _run_dbt("run")
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 20, in _run_dbt
#     raise RuntimeError(f"dbt {command} failed")
# RuntimeError: dbt run failed
# 22:35:56.823 | ERROR   | Task run 'dbt-run-edf' - Finished in state Failed('Task run encountered an exception RuntimeError: dbt run failed')
# 2026-04-12 22:35:56 | ERROR   | prefect.task_runs | Finished in state Failed('Task run encountered an exception RuntimeError: dbt run failed')
# 22:35:57.034 | ERROR   | Flow run 'illegal-puffin' - Encountered exception during execution: RuntimeError('dbt run failed')
# Traceback (most recent call last):
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 988, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 1633, in run_flow_sync
#     engine.call_flow_fn()
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 1008, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\pipeline.py", line 23, in run_pipeline
#     dbt_run()
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\tasks.py", line 1213, in __call__
#     return run_task(
#            ^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1900, in run_task
#     return run_task_sync(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1675, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 611, in result
#     raise self._raised
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1014, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 25, in dbt_run
#     _run_dbt("run")
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 20, in _run_dbt
#     raise RuntimeError(f"dbt {command} failed")
# RuntimeError: dbt run failed
# 2026-04-12 22:35:57 | ERROR   | prefect.flow_runs | Encountered exception during execution: RuntimeError('dbt run failed')
# Traceback (most recent call last):
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 988, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 1633, in run_flow_sync
#     engine.call_flow_fn()
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py", line 1008, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\pipeline.py", line 23, in run_pipeline
#     dbt_run()
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\tasks.py", line 1213, in __call__
#     return run_task(
#            ^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1900, in run_task
#     return run_task_sync(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1675, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 611, in result
#     raise self._raised
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1014, in run_context
#     yield self
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py", line 347, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 25, in dbt_run
#     _run_dbt("run")
#   File "c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py", line 20, in _run_dbt
#     raise RuntimeError(f"dbt {command} failed")
# RuntimeError: dbt run failed
# 22:35:57.068 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a/set_state "HTTP/1.1 201 Created"
# 2026-04-12 22:35:57 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/flow_runs/b1f96014-be0d-45d8-9d17-45bceb7d387a/set_state "HTTP/1.1 201 Created"
# 22:35:57.071 | INFO    | Flow run 'illegal-puffin' - Finished in state Failed('Flow run encountered an exception: RuntimeError: dbt run failed')
# 2026-04-12 22:35:57 | INFO    | prefect.flow_runs | Finished in state Failed('Flow run encountered an exception: RuntimeError: dbt run failed')
# 22:35:57.121 | INFO    | httpx - HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# 2026-04-12 22:35:57 | INFO    | httpx | HTTP Request: POST http://127.0.0.1:8446/api/logs/ "HTTP/1.1 201 Created"
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       2 create_database()
#       3 create_tables()
# ----> 4 run_pipeline()
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flows.py:1882, in Flow.__call__(self, return_state, wait_for, *args, **kwargs)
#    1878     return track_viz_task(self.isasync, self.name, parameters)
#    1880 from prefect.flow_engine import run_flow
# -> 1882 return run_flow(
#    1883     flow=self,
#    1884     parameters=parameters,
#    1885     wait_for=wait_for,
#    1886     return_type=return_type,
#    1887 )
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:1790, in run_flow(flow, flow_run, parameters, wait_for, return_type, error_logger, context)
#    1788         ret_val = run_flow_async(**kwargs)
#    1789     else:
# -> 1790         ret_val = run_flow_sync(**kwargs)
#    1791 except (Abort, Pause):
#    1792     raise
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:1635, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type, context)
#    1632         with engine.run_context():
#    1633             engine.call_flow_fn()
# -> 1635 return engine.state if return_type == "state" else engine.result()
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:538, in FlowRunEngine.result(self, raise_on_failure)
#     536 if self._raised is not NotSet:
#     537     if raise_on_failure:
# --> 538         raise self._raised
#     539     return self._raised
#     541 # This is a fall through case which leans on the existing state result mechanics to get the
#     542 # return value. This is necessary because we currently will return a State object if the
#     543 # the State was Prefect-created.
#     544 # TODO: Remove the need to get the result from a State except in cases where the return value
#     545 # is a State object.
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:988, in FlowRunEngine.run_context(self)
#     984         with _send_heartbeats(self):
#     985             self.logger.debug(
#     986                 f"Executing flow {self.flow.name!r} for flow run {self.flow_run.name!r}..."
#     987             )
# --> 988             yield self
#     989 except TimeoutError as exc:
#     990     self.handle_timeout(exc)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:1633, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type, context)
#    1631     while engine.is_running():
#    1632         with engine.run_context():
# -> 1633             engine.call_flow_fn()
#    1635 return engine.state if return_type == "state" else engine.result()
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\flow_engine.py:1008, in FlowRunEngine.call_flow_fn(self)
#    1006     return _call_flow_fn()
#    1007 else:
# -> 1008     result = call_with_parameters(self.flow.fn, self.parameters)
#    1009     self.handle_success(result)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py:347, in call_with_parameters(fn, parameters)
#     339 """
#     340 Call a function with parameters extracted with `get_call_parameters`
#     341
#    (...)    344 the args/kwargs using `parameters_to_positional_and_keyword` directly
#     345 """
#     346 args, kwargs = parameters_to_args_kwargs(fn, parameters)
# --> 347 return fn(*args, **kwargs)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\pipeline.py:23, in run_pipeline()
#      21 load_staging(engine)
#      22 load_quarantine(engine)
# ---> 23 dbt_run()
#      24 dbt_test()
#      25 cleanup(engine)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\tasks.py:1213, in Task.__call__(self, return_state, wait_for, *args, **kwargs)
#    1207     return track_viz_task(
#    1208         self.isasync, self.name, parameters, self.viz_return_value
#    1209     )
#    1211 from prefect.task_engine import run_task
# -> 1213 return run_task(
#    1214     task=self,
#    1215     parameters=parameters,
#    1216     wait_for=wait_for,
#    1217     return_type=return_type,
#    1218 )
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:1900, in run_task(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1898     return run_task_async(**kwargs)
#    1899 else:
# -> 1900     return run_task_sync(**kwargs)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:1675, in run_task_sync(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1668         with (
#    1669             engine.asset_context(),
#    1670             engine.run_context(),
#    1671             engine.transaction_context() as txn,
#    1672         ):
#    1673             engine.call_task_fn(txn)
# -> 1675 return engine.state if return_type == "state" else engine.result()
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:611, in SyncTaskRunEngine.result(self, raise_on_failure)
#     608 if self._raised is not NotSet:
#     609     # if the task raised an exception, raise it
#     610     if raise_on_failure:
# --> 611         raise self._raised
#     613     # otherwise, return the exception
#     614     return self._raised
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:1014, in SyncTaskRunEngine.run_context(self)
#    1011         if self.is_cancelled():
#    1012             raise CancelledError("Task run cancelled by the task runner")
# -> 1014         yield self
#    1015 except TimeoutError as exc:
#    1016     self.handle_timeout(exc)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:1673, in run_task_sync(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1667         engine.wait_until_ready()
#    1668         with (
#    1669             engine.asset_context(),
#    1670             engine.run_context(),
#    1671             engine.transaction_context() as txn,
#    1672         ):
# -> 1673             engine.call_task_fn(txn)
#    1675 return engine.state if return_type == "state" else engine.result()
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\task_engine.py:1031, in SyncTaskRunEngine.call_task_fn(self, transaction)
#    1029     result = transaction.read()
#    1030 else:
# -> 1031     result = call_with_parameters(self.task.fn, parameters)
#    1032 self.handle_success(result, transaction=transaction)
#    1033 return result
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\prefect\utilities\callables.py:347, in call_with_parameters(fn, parameters)
#     339 """
#     340 Call a function with parameters extracted with `get_call_parameters`
#     341
#    (...)    344 the args/kwargs using `parameters_to_positional_and_keyword` directly
#     345 """
#     346 args, kwargs = parameters_to_args_kwargs(fn, parameters)
# --> 347 return fn(*args, **kwargs)
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py:25, in dbt_run()
#      22 @task(name="dbt-run", cache_policy=NO_CACHE)
#      23 def dbt_run():
#      24     logger.info("Running dbt models...")
# ---> 25     _run_dbt("run")
#
# File c:\Users\zxrco\anaconda3\envs\myenv3\Lib\site-packages\src\tasks\dbt.py:20, in _run_dbt(command)
#      18 if result.returncode != 0:
#      19     logger.error(result.stderr)
# ---> 20     raise RuntimeError(f"dbt {command} failed")
#
# RuntimeError: dbt run failed

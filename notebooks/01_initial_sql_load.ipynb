# %%
from src.pipeline import run_pipeline
from src.db_init.db_setup import create_database, create_tables

# %%
create_database()
create_tables()
run_pipeline()
# Out:
# 19:43:53.572 | INFO    | src.db_init.db_setup - Database 'library' already exists.
# 2026-04-12 19:43:53 | INFO    | src.db_init.db_setup | Database 'library' already exists.
# 19:43:53.631 | INFO    | src.db_init.db_setup - Running 01_schema.sql...
# 2026-04-12 19:43:53 | INFO    | src.db_init.db_setup | Running 01_schema.sql...
# 19:43:53.641 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv2\Lib\site-packages\sql\sql_tables\01_schema.sql
# 2026-04-12 19:43:53 | INFO    | src.utils.sql_execute | Executed: c:\Users\zxrco\anaconda3\envs\myenv2\Lib\site-packages\sql\sql_tables\01_schema.sql
# 19:43:53.643 | INFO    | src.db_init.db_setup - Running 02_raw_schema.sql...
# 2026-04-12 19:43:53 | INFO    | src.db_init.db_setup | Running 02_raw_schema.sql...
# 19:43:53.685 | INFO    | src.utils.sql_execute - Executed: c:\Users\zxrco\anaconda3\envs\myenv2\Lib\site-packages\sql\sql_tables\02_raw_schema.sql
# ...

# %%
from src.pipeline import run_pipeline
from src.db_init.db_setup import create_database, create_tables

# %%
create_database()
create_tables()
run_pipeline()
# Out:
# 14:00:14.045 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8132
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 14:00:23.286 | INFO    | Flow run 'vagabond-bandicoot' - Beginning flow run 'vagabond-bandicoot' for flow 'books-pipeline'
# Data exists in D:\projects\sql-books\data\01_raw. Skipping.
# 14:00:23.321 | INFO    | Task run 'download-data-584' - Finished in state Completed()
# 14:00:33.891 | INFO    | Task run 'validate-data-fd5' - Finished in state Completed()
# 14:02:28.818 | INFO    | Task run 'load-sql-cf2' - Finished in state Completed()
# 14:02:28.869 | INFO    | Task run 'cleanup-staging-245' - Finished in state Completed()
# 14:02:29.597 | INFO    | Flow run 'vagabond-bandicoot' - Finished in state Completed()

# %%
import getpass

from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# %%
# %load_ext sql

password = getpass.getpass('Enter database user password: ')

conn_str = f'postgresql+psycopg2://postgres:{password}@localhost:5432/postgres'
engine = create_engine(conn_str)
# %sql engine

# %sql --file ../sql/terminate_backend_sessions.sql
# %sql --file ../sql/db_drop.sql
# %sql --file ../sql/db_create.sql

conn_str = f'postgresql+psycopg2://postgres:{password}@localhost:5432/library'
engine = create_engine(conn_str)
# %sql engine

# %sql --file ../sql/drop_main.sql
# %sql --file ../sql/schema.sql

# %sql --file ../sql/drop_staging.sql
# %sql --file ../sql/staging_schema.sql

# %sql --file ../sql/sql_load/01_load_staging.sql
# %sql --file ../sql/sql_load/02_load_authors.sql
# %sql --file ../sql/sql_load/03_load_publishers.sql
# %sql --file ../sql/sql_load/04_load_books.sql
# %sql --file ../sql/sql_load/05_load_users.sql
# %sql --file ../sql/sql_load/06_load_ratings.sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# 5 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 271360 rows affected.
# 278858 rows affected.
# 1149780 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 102023 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# ...

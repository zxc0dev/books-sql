# %%
import getpass

from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# %%
# %load_ext sql

password = getpass.getpass('Enter database user password: ')

conn_str = f'postgresql+psycopg2://postgres:{password}@localhost:5432/postgres'
engine = create_engine(conn_str)
# %sql engine

# %sql --file ../sql/sql_create/terminate_backend_sessions.sql
# %sql --file ../sql/sql_create/db_drop.sql
# %sql --file ../sql/sql_create/db_create.sql

conn_str = f'postgresql+psycopg2://postgres:{password}@localhost:5432/library'
engine = create_engine(conn_str)
# %sql engine

# %sql --file ../sql/sql_create/main_drop.sql
# %sql --file ../sql/sql_create/schema.sql

# %sql --file ../sql/sql_create/staging_drop.sql
# %sql --file ../sql/sql_create/staging_schema.sql

# %sql --file ../sql/sql_create/quarantine_drop.sql
# %sql --file ../sql/sql_create/quarantine_schema.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/postgres'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 4 rows affected.
# 2 rows affected.
# 2 rows affected.
# 1 rows affected.
# +-------------+---------------+------------------+-------------+---------------+------------------+---------------------+
# | total_books | total_authors | total_publishers | total_users | total_ratings | implicit_ratings | avg_explicit_rating |
# +-------------+---------------+------------------+-------------+---------------+------------------+---------------------+
# |      0      |       0       |        0         |      0      |       0       |        0         |         None        |
# +-------------+---------------+------------------+-------------+---------------+------------------+---------------------+

# %%
# %sql --file ../sql/sql_load/01_load_staging.sql
# %sql --file ../sql/sql_load/02_data_quality_check.sql
# %sql --file ../sql/sql_load/03_load_authors.sql
# %sql --file ../sql/sql_load/04_load_publishers.sql
# %sql --file ../sql/sql_load/05_load_books.sql
# %sql --file ../sql/sql_load/06_load_users.sql
# %sql --file ../sql/sql_load/07_load_ratings.sql
# Out:
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 271360 rows affected.
# 278858 rows affected.
# 1149780 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 102023 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# 16807 rows affected.
# Running query in 'postgresql+psycopg2://postgres:***@localhost:5432/library'
# RuntimeError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type integer: "DK Publishing Inc"
#
# [SQL: INSERT INTO books (isbn, book_title, author_id, year_published, publisher_id)
#     SELECT DISTINCT
#         s.ISBN,
#         s.book_title,
#         a.id,
#         NULLIF(CAST(s.year_of_publication AS INT), 0),
#         p.id
#     FROM staging_books s
#     LEFT JOIN authors a ON a.author_name = s.book_author
#     LEFT JOIN publishers p ON p.publisher_name = s.publisher
#     WHERE s.ISBN IS NOT NULL
#       AND s.book_title IS NOT NULL]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
